# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Podemos personalizar mejor nuestros gráficos con diferentes colores y estilos, así, se entenderá mucho mejor nuestras gráficas.
#
# Cómo agregar colores y estilos en Matplotlib
#
# Estilos de gráficas que hay
#
# print(plt.style.available)
# ---> Muestra los stilos que tiene matplot
#
# Usar un estilo de grilla
#
# plt.style.use('seaborn-whitegrid')
#
#
# Personalizar colores y estilos en Matlab
#
# fig, ax = plt.subplots(figsize = (6,6))
# ax.plot(x,x+1, 'r--')
# ax.plot(x,x+2, 'bo-')
# ax.plot(x,x+3, 'g.:')
# ax.plot(x,x+4, 'purple')
#
# Personalizar colores y estilos en Pyplot
#
# Para personalizar con pyplot es un poco más largo cuando programamos, pero se puede personalizar muchísimo más
#
# Color
#
# fig, ax = plt.subplots(figsize = (6,6))
# ax.plot(x,x+1,color = '#D426C8') ---> Color RGB
# ax.plot(x,x+2,color = '#66FF89')
#
# ax.plot(x,x+3,color = 'blue') --> Color común
# ax.plot(x,x+4, color = 'black')
#
# Transparencia (alpha) y grosor (linewidth)
#
# fig, ax = plt.subplots(figsize = (6,6))
# ax.plot(x,x+1,color = '#D426C8', alpha= 0.5, linewidth= 18)
# ax.plot(x,x+2,color = '#66FF89', linewidth= 3)
# ax.plot(x,x+3,color = 'blue', linewidth= 5)
# ax.plot(x,x+4, color = 'black', alpha = 0.3, linewidth= 12)
#
# Estilo (linestyle) y marcadores (marker)
#
# fig, ax = plt.subplots(figsize = (6,6))
# ax.plot(x,x+3,color = 'blue', linestyle = 'dashed', marker = 'x')
# ax.plot(x,x+4, color = 'black',linestyle = '--', marker = 'P')
#
# Tamaño de marcadores (markersize) y color (markerfacecolor)
#
# fig, ax = plt.subplots(figsize = (6,6))
# ax.plot(x,x+3,color = 'blue', linestyle = 'dashed', marker = '8', markersize = 10, markerfacecolor= "#37D842")
#
# ax.plot(x,x+4, color = 'black',linestyle = '--', marker = 'P', markerfacecolor="#FF0000")

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("dark_background")
fig,axes=plt.subplots(figsize=(8,8))
axes.plot(x,x+1,"r--")
axes.plot(x,x+2,"b:")
axes.plot(x,x+3,"y.-")
axes.plot(x,x+4,"go");

# %%
plt.style.use("dark_background")
fig,axes=plt.subplots(figsize=(8,8))

axes.plot(x,x+1,color="green",alpha=0.8,linewidth=5,linestyle="-",marker="o",markersize=10,markerfacecolor="#ccffcc")

axes.plot(x,x+2,color="blue", alpha=0.5,linewidth=8,linestyle="--",marker="x")

axes.plot(x,x+3,color="#66ff66",alpha=0.7,linewidth=3,linestyle="dashed",marker="v")

axes.plot(x,x+4,color="#ccffcc",alpha=0.3,linewidth=2,linestyle=":",marker="P");

# %%
for i in plt.style.available:
  plt.style.use(i)
  fig, axes = plt.subplots(figsize=(5,5))
  axes.plot(x,y)
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_17340\1186367159.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(figsize=(5,5))

# %%
plt.style.use("dark_background")
fig,ax=plt.subplots(figsize=(8,8))
ax.plot(x,x+1,"r")
ax.plot(x,x+2,"b")
ax.plot(x,x+3,"y")
ax.plot(x,x+4,"g");

# %%
plt.style.use("bmh")
fig,ax=plt.subplots(figsize=(8,8))
ax.plot(x,x+1,color="red",alpha=0.3,linewidth=5,linestyle="-",marker="o",markersize=10,markerfacecolor="red")
ax.plot(x,x+2,color="#000000",linewidth=10,linestyle="--",marker="8",markersize=8,markerfacecolor="black")
ax.plot(x,x+3,color="yellow",linewidth=8,linestyle="dashed",marker="v",markersize=6,markerfacecolor="yellow")
ax.plot(x,x+4,color="blue",linewidth=7,linestyle=":",marker="P",markersize=7,markerfacecolor="purple");

# %%
plt.style.use("classic")
fig,ax=plt.subplots(figsize=(8,8))
ax.plot(x,x+1)
ax.plot(x,x+2)
ax.plot(x,x+3)
ax.plot(x,x+4);

# %%
for i in plt.style.available:
  plt.style.use(i)
  fig, ax = plt.subplots(figsize=(5,5))
  ax.plot(x, y)
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_11764\2534319048.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(5,5))
