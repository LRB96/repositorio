# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#                                     Apuntes
#
# Jintplot y pairplot sirven con un dataset de entrada.
#
# Siplemente se hace limpieza de los datos, y con estos metodos se entiende que relaciones hay entre variables, etc.
#
# Jintplot une 2 graficas distintas en una sola.
#
# Mrginal_ticks=True muestra una pequeña tabla para la gráfica exterior.
#
# Cn marginal_kws se pueden agregar diferentes parámetros.
#
# Pairplot sirve para relacion entre variables numericas.
#
# Se pueden analizar todas las variables numericas en una sola graficas.
#
# Un diagrama de kde es uno de densidades.

# %% [markdown]
# Jointplot y Pairplot son funcionalidades de Seaborn, porque con un solo comando se puede generar varios tipos de gráficos.
#
#     Ejercicio práctico con Jointplot y Pairplot
#
# Importamos datos
#
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# tips = sns.load_dataset('tips')
# tips.head()

# %% [markdown]
#     1. Con Joinplot
#
# Joinplot une 2 distintas gráficas en una sola
#
# sns.jointplot(data=tips, x='total_bill', y= 'tip', hue = 'sex');
#
# Agregar más argumentos para poder hacer un mejor análisis

# %% [markdown]
# sns.jointplot(data=tips, x='total_bill', y= 'tip', hue='sex', kind= 'hist', marginal_ticks=True,
#
# Muestra una pequeña tabla para la gráfica exterior.
#
# marginal_kws=dict(bins= 25, fill = True, multiple= 'dodge'));
#
# Marginal_kws se le pueden agregar diferentes parámetros

# %% [markdown]
#     2. Con Pairplot
#
# Pairplot correlaciona todas las variables numéricas que hay en el dataset
#
# sns.pairplot(data= tips);
#
# Solo muestra una esquina del pairplot, eliminando así, las gráficas repetidas

# %% [markdown]
# sns.pairplot(data= tips, corner=True);

# %%
tips=sns.load_dataset("tips").rename(columns=str.lower)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="sex");

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="sex",kind="hist",
              marginal_ticks=True,marginal_kws=dict(bins=25,fill=True,multiple="dodge"));

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",hue="sex",kind="kde");

# %%
sns.pairplot(data=tips,hue="sex",palette="coolwarm",corner=True,kind="scatter");
